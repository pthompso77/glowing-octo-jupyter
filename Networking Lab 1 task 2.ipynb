# %%
import sys

def http_parse(msg):
    if (len(msg) < 3):
        PAGE = '/'
    else:
        PAGE = msg
    return PAGE
# Out:
# 'index.html'

# %%
# HTTP Request

if(len(sys.argv)>2):
    PAGE = http_parse(sys.argv[2])
else:
    PAGE = '/'

print('let us fetch',PAGE)

s = socket.socket(socket.AF_INET,socket.SOCK_STREAM)
s.settimeout(60)
SERV = (sys.argv[1],80)
reqHeader = 'GET {0} HTTP/1.0\r\n\r\n'.format(PAGE)

s.connect(SERV)
s.sendall(str.encode(reqHeader))

response = b''
while True:
    recv = s.recv(1024)
    if not recv:
        break
    response += recv
    
print(response.decode('utf-8','ignore'))
s.close()
# Out:
# let us fetch /Users/lex/Library/Jupyter/runtime/kernel-7c260f0e-deb3-4d13-88d7-18c77930cb13.json
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# <ipython-input-22-80586f7c81aa> in <module>
#      12 reqHeader = 'GET {0} HTTP/1.0\r\n\r\n'.format(PAGE)
#      13
# ---> 14 s.connect(SERV)
#      15 s.sendall(str.encode(reqHeader))
#      16
#
# gaierror: [Errno 8] nodename nor servname provided, or not known

# %%
# Echo Server
import socket

HOST = '127.0.0.1'
PORT = 6055

with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
    s.bind((HOST,PORT))
    s.listen()
    s.settimeout(600) #in seconds
    conn, addr = s.accept() # this is a NEW SOCKET, not the one for listening from above
    with conn:
        print('Connected by:',addr)
        while True:
            data = conn.recv(1024)
            print('Received:',data)
            if not data:
                break
            conn.sendall(data)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# <ipython-input-24-1bc47d7a2c43> in <module>
#       9     s.listen()
#      10     s.settimeout(600) #in seconds
# ---> 11     conn, addr = s.accept() # this is a NEW SOCKET, not the one for listening from above
#      12     with conn:
#      13         print('Connected by:',addr)
#
# /anaconda3/lib/python3.7/socket.py in accept(self)
#     210         For IP sockets, the address info is a pair (hostaddr, port).
#     211         """
# --> 212         fd, addr = self._accept()
#     213         sock = socket(self.family, self.type, self.proto, fileno=fd)
#     214         # Issue #7995: if no default timeout is set and the listening
#
# timeout: timed out

# %%
# Task 2: Write a HTTP server python program.  
# The program should parse HTTP v1.0 requests, if a GET request asks for a file that is in the local directory, 
# respond with the 200 code and the contents of that file along with the correct content-type 
# (HTML file only for now).  If the file does not exist, return a 404 code.
print('Closing socket')
try:
    s.close()
except:
    print('except')
# Out:
# Closing socket

# %%
try:
    s.close()
except:
    print('except')
    
print("Creating socket")
s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)

print("Binding to localhost on port 60112")
s.bind(('127.0.0.1', 60112))
print("Connection success!")
print('Listening')
s.listen()
s.settimeout(20)
print('New accept socket\n')
conn, addr = s.accept() # this is a NEW SOCKET, not the one for listening from above
with conn:
    print('Connected by:',addr)
    while True:
        data = conn.recv(1024)
        print('Received:',data)
        if not data:
            break
        conn.sendall(data)
        
        
# except(socket.error, msg):
#     print("Failed to create and connect. Error code: " + str(msg[0]) + " , Error message : " + msg[1])
#     exit()

# if options.data:
#     print "Data parameter received."
#     data = options.data
# else:
#     data = raw_input("Enter data to send to server: ")  
# print 'Attempting to send data over the socket...'
# sock.sendall(data)
# print 'Data sent to server! Now waiting for response...'
# while 1:
#     data = sock.recv(4096)
#     print "Received response:" + str(data)

print('Closing socket')
s.close()
# del sock
# Out:
# Creating socket
# Binding to localhost on port 60112
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-12-ecb2b088e36b> in <module>
#      13
#      14 print("Binding to localhost on port 60112")
# ---> 15 s.bind(('127.0.0.1', 60112))
#      16 print("Connection success!")
#      17 print('Listening')
#
# OSError: [Errno 48] Address already in use

# %%
print('Closing socket')
try:
    s.close()
except:
    print('except')
# Out:
# Closing socket

# %%
# The primary socket API functions and methods in this module are:
# socket()
# bind()
# listen()
# accept()
# connect()
# connect_ex()
# send()
# recv()
# close()
