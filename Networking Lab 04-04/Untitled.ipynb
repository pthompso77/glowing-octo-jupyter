# %%
import socket
import ssl

# %%
# hostname = 'www.python.org'
# # PROTOCOL_TLS_CLIENT requires valid cert chain and hostname
# context = ssl.SSLContext(ssl.PROTOCOL_TLS_CLIENT)
# context.load_verify_locations('path/to/cabundle.pem')

# with socket.socket(socket.AF_INET, socket.SOCK_STREAM, 0) as sock:
#     with context.wrap_socket(sock, server_hostname=hostname) as ssock:
#         print(ssock.version())

serv = ('ssl3270.nccourts.org',2023)
context = ssl.SSLContext(ssl.PROTOCOL_TLS_CLIENT)
context.load_verify_location('')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-78d3067eaf49> in <module>
#      10 serv = ('ssl3270.nccourts.org',2023)
#      11 context = ssl.SSLContext(ssl.PROTOCOL_TLS_CLIENT)
# ---> 12 context.load_verify_location('')
#
# AttributeError: 'SSLContext' object has no attribute 'load_verify_location'

# %%
b = b'hey'
b.startswith(b'h')
# Out:
# True
